# %% [markdown]
# (SAMPLE Data) Netflix User Data Analysis by Rahil Mavani

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
usrbase = pd.read_csv("C:/Users/mavan/JupyterWork/netflix_data.csv")

# %%
usrbase
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
usrbase.head()
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
usrbase.tail()
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
#             Country  Age  Gender    Device Plan Duration
# 2495          Spain   28  Female  Smart TV       1 Month
# 2496          Spain   33  Female  Smart TV       1 Month
# 2497  United States   38    Male    Laptop       1 Month
# 2498         Canada   48  Female    Tablet       1 Month
# 2499  United States   35  Female  Smart TV       1 Month

# %%
usrbase.describe()
# Out:
#           User ID  Monthly Revenue          Age
# count  2500.00000      2500.000000  2500.000000
# mean   1250.50000        12.508400    38.795600
# std     721.83216         1.686851     7.171778
# min       1.00000        10.000000    26.000000
# 25%     625.75000        11.000000    32.000000
# 50%    1250.50000        12.000000    39.000000
# 75%    1875.25000        14.000000    45.000000
# max    2500.00000        15.000000    51.000000

# %%
#Pie-chart for type of subscription analysis
sub_type = usrbase["Subscription Type"].value_counts()
plt.pie(sub_types, labels=sub_type.index, autopct='%1.3f%%', startangle=45)
plt.title("Subscription Types")
plt.show()

# %%
#Plot for Gender Analysis
gender_plot = sns.countplot(x = "Gender", data = usrbase)
plt.xlabel("Gender")
plt.ylabel("Amount of People")
plt.title("Gender Distribution")
gender_plot.bar_label(gender_plot.containers[0]);
plt.show()

# %%
#Plot for Age Group Analysis
age_plot = sns.countplot(x = "Age", data = usrbase)
plt.xlabel("Age")
plt.ylabel("Amount of People")
plt.title("Age Distribution")
age_plot.bar_label(age_plot.containers[0])
plt.show()

# %%
#Country wise Distrubution
plt.figure(figsize = (12,5))
cntry_plot = sns.countplot(x = "Country", data = usrbase)
plt.xlabel("Country")
plt.ylabel("Amount of People")
plt.title("Countrywise Distribution")
cntry_plot.bar_label(cntry_plot.containers[0]);
plt.show()

# %%
usrbase.Device.value_counts().plot(kind='pie' ,autopct='%1.3f%%')
plt.show()

# %%
#Type of Plan with Revenue
rev_plot = sns.barplot(x="Subscription Type", y="Monthly Revenue", data = usrbase)
plt.title("Revenue with respect to Subscription Type")
plt.xlabel("Subscription Type")
plt.ylabel("Monthly Revenue")
rev_plot.bar_label(rev_plot.containers[0]);
plt.show()

# %%
#Expressing Comparative analysis between gender and Monthly Revenue
rev_plot = sns.barplot(x="Gender", y="Monthly Revenue", data = usrbase)
plt.title("Revenue with respect to Gender")
plt.xlabel("Gender")
plt.ylabel("Monthly Revenue")
rev_plot.bar_label(rev_plot.containers[0]);
plt.show()

# %%
usrbase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
#Countries giving amount of Revenue
plt.figure(figsize = (12,3.5))
revcon_plot = sns.barplot(x = "Country", y = "Monthly Revenue", data = usrbase)
plt.title("Revenue analysis per country")
plt.xlabel("Country")
plt.ylabel("Monthly Revenue")
revcon_plot.bar_label(revcon_plot.containers[0]);

# %%
usrbase
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
usrbase["Birth Year"] = 2023 - usrbase["Age"]
usrbase.head(10)
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
# 5        6           Premium               15  18-03-22          27-06-23
# 6        7          Standard               12  09-12-21          25-06-23
# 7        8             Basic               10  02-04-23          24-06-23
# 8        9          Standard               12  20-10-22          23-06-23
# 9       10           Premium               15  07-01-23          22-06-23
#
#           Country  Age  Gender      Device Plan Duration  Birth Year
# 0   United States   28    Male  Smartphone       1 Month        1995
# ...

# %%
genz = 0
genx = 0
millennial = 0
for i in usrbase["Birth Year"]:
    if i in range(1965,1979):
        genx += 1
    elif i in range(1980,1994):
        millennial += 1
    else:
        genz += 1
    continue
print("Generation wise Users :")
print(f"Generation X : {genx}, Millennials : {millennial}, Generation Z : {genz}")
# Out:
# Generation wise Users :
# Generation X : 674, Millennials : 1433, Generation Z : 393

# %%
#Heatmap
hmap = usrbase[["Age", "Monthly Revenue"]].corr()
sns.heatmap(hmap, annot=True, cmap="PiYG")
plt.title("Correlation")
plt.show()

# %% [markdown]
# **Conclusions** :
#     1. Most users are from United States and Spain.
#     2. Most of the users belong to Millennial age group.
#     3. Male to Femlae ration in userbase as well as in revenue base is nearby same.
#     4. There are around 9-10% more users opting for Basic plan.
#     5. Devices used are almost of same ratio at around 25% for Smartphone, Tablet, Laptop and Smart TV.
#     6. All the Subscription types gives similar amount of Revenue with Premium being the most.
#     7. United Kingdom contributes highest in monthly revenue with France being second and United States being the Third.
